# %%
import pickle

# %%
with open('runs/fid_stats.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
b
# Out:
# {0: [289.12656194051783, 281.17438353255784],
#  1: [277.35463060623954, 268.284941105053],
#  2: [263.7236250716785, 254.32157805872322],
#  3: [249.47260508809438, 240.90000367684098],
#  4: [235.89082656143844, 228.91788902769034],
#  5: [223.66816373896086, 218.47249130795024],
#  6: [212.66181643047926, 208.91531736256775],
#  7: [202.28846732806016, 199.49085201190144],
#  8: [191.84355661394363, 189.5905346457236],
#  9: [180.9583179625517, 179.0301561580119],
#  10: [169.50207960145636, 167.8609463825954],
#  11: [157.41711747078864, 155.8839031705681],
#  12: [144.34188213674622, 142.95250253089247],
#  13: [130.3183716747859, 128.97171299946064],
#  14: [115.50499565105765, 114.23813371084906],
#  15: [100.47773954373376, 99.51335917889213],
#  16: [85.88519676454185, 85.08956749582946],
#  17: [72.33007627838685, 71.7178293095237],
#  18: [60.25800607903086, 59.67673924919629],
#  19: [49.837620430547624, 49.23566361174893],
#  20: [41.02938016158079, 40.43120160950949],
# ...

# %%
import matplotlib.pyplot as plt


for key in list(b.keys()):
    plt.plot(b[key], label=key)
    plt.legend()
    plt.ylim(1.5, 10)
plt.hlines(2.55, 0, 22, color='black')
